# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# %%
from google.colab import files
src = list(files.upload().values())[0]
#open('mylib.py','wb').write(src)
open('loadibex.py','wb').write(src)
from loadibex import load_ibexfile_std as loadi
# Out:
#      <input type="file" id="files-1a66feeb-b6b6-4006-8e7e-7106ecaf2621" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a66feeb-b6b6-4006-8e7e-7106ecaf2621">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/SHIELD/Summer_School/SummerSchool25/Materials/ENA_Maps_Shield
# %pwd
# Out:
# /content/drive/MyDrive/SHIELD/Summer_School/SummerSchool25/Materials/ENA_Maps_Shield
# '/content/drive/MyDrive/SHIELD/Summer_School/SummerSchool25/Materials/ENA_Maps_Shield'

# %%
import json
from loadibex import load_json, load_ibexfile_std as load

# %%
# !pwd
# Out:
# /content/drive/MyDrive/SHIELD/Summer_School/SummerSchool25/Materials/ENA_Maps_Shield

# %%
jsn = load_json(filename='drive/MyDrive/SHIELD/Summer_School/SummerSchool25/Materials/ENA_Maps_Shield/ibex_data')

# %%
jsn = json.load('ibex_data.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-16708805d7af> in <cell line: 0>()
# ----> 1 jsn = json.load('ibex_data.json')
#
# /usr/lib/python3.11/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'

# %%
src1 = list(files.upload().values())[0]
open('SphereRotate.py','wb').write(src1)
import SphereRotate
# Out:
#      <input type="file" id="files-89f3a5f7-17d1-449e-8cf1-2b1dd911aa66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89f3a5f7-17d1-449e-8cf1-2b1dd911aa66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
src2 = list(files.upload().values())[0]
open('map_rotate.py','wb').write(src2)
import map_rotated
# Out:
#      <input type="file" id="files-814a9534-ca1c-40a9-88ff-9f65c91d14e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-814a9534-ca1c-40a9-88ff-9f65c91d14e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#==============================
alf = 35  # angle between old pole and new pole
phi = -30  # longitude where the new pole is
th = 0 # end rotation towards positive azimuth
#==============================
